# %%
import psycopg2

import pandas as pd
import bokeh
import polars as pl
import chardet


fp = r'C:\Users\MelissaLu\OneDrive - Metrolinx\Desktop\Projects\Bus_Work_Order_Data_Spy.csv'

with open(fp,'rb') as f:
    enc = chardet.detect(f.read())
    print(enc)

data = pl.read_csv(fp, encoding=enc['encoding'],ignore_errors=True)

display(data.head())
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# shape: (5, 100)
# ┌─────────┬────────────┬──────────┬───────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ Equipme ┆ Equipment  ┆ Work     ┆ Descripti ┆ ... ┆ From       ┆ From Relat ┆ From       ┆ From       │
# │ nt      ┆ Descriptio ┆ Order    ┆ on        ┆     ┆ Reference  ┆ ionship    ┆ Vertical   ┆ Vertical   │
# │ ---     ┆ n          ┆ ---      ┆ ---       ┆     ┆ Point      ┆ Type       ┆ Offset     ┆ Offset     │
# │ str     ┆ ---        ┆ i64      ┆ str       ┆     ┆ ---        ┆ ---        ┆ ---        ┆ Type       │
# │         ┆ str        ┆          ┆           ┆     ┆ str        ┆ str        ┆ str        ┆ ---        │
# │         ┆            ┆          ┆           ┆     ┆            ┆            ┆            ┆ str        │
# ╞═════════╪════════════╪══════════╪═══════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# ...
