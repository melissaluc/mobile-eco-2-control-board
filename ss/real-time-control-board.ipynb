# %%
"""
Scrape the Control Board for real-time alerts

Script will keep running and need to be initialted again when connection site is lost
refresh browser or press refresh tag below

REFRESH should be performed at intervals
left table only 10 
http://cavl-pvme201:8090/MOBILEvhm/DevicesGroups/VHM/VehicleDataGridPartial


"""
import os
import time
import logging
import re
from datetime import date, datetime

import pandas as pd

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options as ChromeOptions



# initialize chrome driver
# TODO  DeprecationWarning: executable_path has been deprecated, please pass in a Service object
options = ChromeOptions()
# options.add_argument("--headless=new")
# options.add_argument("--window-size=1920,1200")
options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=options)
driver.maximize_window()
driver.implicitly_wait(30)

url = r"http://cavl-pvme201:8090/MOBILEvhm/Login?ReturnUrl=%2fMOBILEvhm%2fDevicesGroups%2fVHM" 
driver.get(url)

# Mobile-Eco-2 Credentials
username = "inita"
password = "init"

# Login
driver.find_element("id", "UserShortName").send_keys(username)
driver.find_element("id", "Password").send_keys(password)

driver.find_element(By.XPATH, "//div[input/@name='loginRequest']/button[1]").click()

# Navigate NAV for Dashboard | Control Board | Veh & Components | Realtime Cockpit | Config | Fleet History
URLS = {
        "fleetHistory":r"http://cavl-pvme201:8090/MOBILEvhm/DevicesGroups/FleetHistory",
        "vehHistory":r"http://cavl-pvme201:8090/MOBILEvhm/DevicesGroups/History",
        "ctrlBoard":r"http://cavl-pvme201:8090/MOBILEvhm/DevicesGroups/VHM",
        }

# NAVIGATE to control board
driver.get(URLS["ctrlBoard"])



# APPLY filters
# INPUT current date into LAST CHANGE field
# TODO include time "05/03/2023 09:02:40"
currentDATE = date.today().strftime("%d/%m/%Y")
currentTIME = datetime.now().strftime("%H:%M:%S")
currentHOUR = datetime.now().strftime("%H")
input_DT = currentDATE #+" "+currentHOUR
# lastChange = driver.find_element(By.XPATH,'//*[@id="vehicleGrid_DXFREditorcol1_I"]').send_keys(input_DT)

# Wait for page to load
time.sleep(10)

# DETECT precence of Child Errors
# TODO GET all OP veh w/ child errors
# SET Child Errors Select All
#---------Warning FlashingSlow | Off | On (either or)
#---------Mal Function Indicator (MIL) Off | On (either or)
childError_filter = driver.find_element(By.XPATH,'//*[@id="vehicleGrid_col8"]/table/tbody/tr/td[2]/img').click()
childError_filter_select_all_checkbox = driver.find_element(By.XPATH,'//*[@id="vehicleGrid_HFSACheckBox"]').click()
childError_filter_OK = driver.find_element(By.XPATH,'//*[@id="vehicleGrid_DXHFP_TPCFCm1_O"]').click()

# Wait for filters to APPLY
time.sleep(10)
num_pages = driver.find_element(By.XPATH,'//*[@id="vehicleGrid_DXPagerBottom"]/b[1]').text
next_page_li_idx = num_pages.split(" ")[3]


def tableExtract(veh_id):
    """
    This function extracts additional detail on the vehicle errors
    Fault Codes
    Error Messages
    Error value readings

    """
    print("TableExtracter fucntion called")
    j=0
    err_rows = []
    while True:
        try:
            time.sleep(5)
            time_err = driver.find_element(By.XPATH,f'//*[@id="messagesGrid_DXDataRow{j}"]/td[1]').text
            # print(time_err)
            comp_err = driver.find_element(By.XPATH,f'//*[@id="messagesGrid_DXDataRow{j}"]/td[2]').text
            # print(comp_err)
            code_err = driver.find_element(By.XPATH,f'//*[@id="messagesGrid_DXDataRow{j}"]/td[3]/span').text
            # print(code_err)
            status_err_icon = driver.find_element(By.XPATH,f'//*[@id="messagesGrid_DXDataRow{j}"]/td[4]/div')
            status_err=status_err_icon.get_attribute("title")
            # print(status_err)
            msg_err_elem = driver.find_element(By.XPATH,f'//*[@id="messagesGrid_DXDataRow{j}"]/td[5]')
            msg_err = msg_err_elem.get_attribute("textContent")
            
            msg_dict = {
                'failure code':"",
                'SPN':"",
                'FMI':"",
                'current value':"",
                'alarm type':"",
                'mode':"",
                'ecuname':"",
                }
            
            # Parse message
            for msg in msg_dict:
                pat=fr'{msg}:(.*?)[;,)]'
                # print(re.findall(pat,msg_err))
                # # print("printing msg_err----",msg_err)
                if re.search(pat,msg_err):
                    msg_value = re.findall(pat,msg_err)
                    msg_dict[msg]=msg_value[0]
                    # print(msg_value)
                else:
                    msg_dict[msg]=None

            # Error message j for veh at row i 
            err_row = {
                "veh_id":veh_id,
                "time":time_err,
                "component":comp_err,
                "error_code":code_err,
                "status":status_err,
                "message":msg_dict,
                    }
        
            comb_err_row = (err_row | msg_dict)
            err_rows.append(comb_err_row)
            # print(err_rows)
            j+=1
        except Exception:
            print("no more err to click ")
            break
    return err_rows


def page_turner(idx):
        print("page_turner function called")        
        next_page = driver.find_element(By.XPATH,f'//*[@id="vehicleGrid_DXPagerBottom"]/a[{idx}]')
        next_page.click()
        print("turned to next page -->")

    
def vehGridTableExtracter(i):
    print("vehGridTableExtracter fucntion called")
    # Veh grid indexer
    
    vehGridDataList = []
    # Loop row by row vehicle grid
    while True:
        try:
            vehgrid_row = driver.find_element(By.XPATH,f'//*[@id="vehicleGrid_DXDataRow{i}"]').click()
            veh_id = driver.find_element(By.XPATH,f'//*[@id="vehicleGrid_DXDataRow{i}"]/td[1]').text
            time.sleep(5)
            
            # Call function to extract veh incident descriptions for veh at row i
            errExtract = tableExtract(veh_id)
            print(errExtract)
            vehGridDataList.append(errExtract)
            i+=1    
            print(i,"/n",veh_id)
        except Exception:
            print("no more to click: end of page")
            break
    
    return [vehGridDataList,i]

def vehGridTableParser(dataList):
    print("Enter parser\n---\n",dataList)
    df_list = []
    for veh in dataList:
        print(veh)
        for r in veh:
            df = pd.DataFrame(veh).drop(columns=["message"])
            df_list.append(df)

    try:
        data = pd.concat(df_list).reset_index().drop(columns=["index"])
        return data
    except Exception:
        return print("could not parse data in vehGridTableParser")

df_list_pages = []
pg = 1
idx=0
while True:
    print("entered while loop")
    print(f"Page {pg}")
    extractVehGrid = vehGridTableExtracter(idx)
    data_list = extractVehGrid[0]
    # print("printing data_list from extractor\n-----\n",data_list)
    df_page = vehGridTableParser(data_list)
    df_list_pages.append(df_page)
    idx=extractVehGrid[1]+1
    if pg < (int(next_page_li_idx)):
        pg+=1
        page_turner(next_page_li_idx)
    else:
        break
    time.sleep(10)



# Refresh vehicle grid
# refresh = driver.find_element(By.XPATH,'//*[@id="forceRefresh"]/a').click()

close_browser = driver.quit()

data = pd.concat(df_list_pages)

rename_dict = {
        "time":"timestamp",
        "failure code":"failure_code",
        "current value":"current_value",
        "alarm type":"alarm_type",
        }
data.rename(columns=rename_dict,inplace=True)


# credentials
db = "mx_tester_db"
db_table = "mbl_eco2_ctrl_brd"
db_username ='postgres'
db_password='mxpassword'
port_no= '5432'
host = 'localhost'

#establishing the connection
conn = psycopg2.connect(
   database=db, user=db_username, password=db_password, host=host, port= port_no
)
#Creating a cursor object using the cursor() method

# for 
# data.to_sql(
#       name=db_table,
#       conn=conn,
#       if_exists="fail"
#       chunksize=1
# )
# Out:
# entered while loop
# Page 1
# vehGridTableExtracter fucntion called
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8330', 'time': '11/03/2023 18:12:22', 'component': '2016 Enviro500 SuperLo Diesel 8330', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 1 /n 8330
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8310', 'time': '11/02/2022 12:01:22', 'component': '2016 Enviro500 SuperLo Diesel 8310', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 2 /n 8310
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2614', 'time': '14/07/2021 15:41:34', 'component': '2015 D4500 Diesel 2614', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 3 /n 2614
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8326', 'time': '08/02/2023 14:26:36', 'component': '2016 Enviro500 SuperLo Diesel 8326', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 4 /n 8326
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8325', 'time': '11/03/2023 18:36:16', 'component': '2016 Enviro500 SuperLo Diesel 8325', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '516.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '516.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 5 /n 8325
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8383', 'time': '11/03/2023 14:20:25', 'component': '2018 Enviro500 SuperLo Diesel 8383', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 6 /n 8383
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8448', 'time': '11/03/2023 05:53:08', 'component': '2019 Enviro500 SuperLo Diesel 8448', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 7 /n 8448
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8460', 'time': '09/03/2023 10:08:23', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8460', 'time': '09/03/2023 10:08:21', 'component': '2019 Enviro500 SuperLo Diesel 8460', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 8 /n 8460
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8343', 'time': '08/03/2023 22:19:02', 'component': '2017 Enviro500 SuperLo Diesel 8343', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 9 /n 8343
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8436', 'time': '29/12/2022 14:20:13', 'component': '2019 Enviro500 SuperLo Diesel 8436', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 10 /n 8436
# no more to click: end of page
# Enter parser
# ---
#  [[{'veh_id': '8330', 'time': '11/03/2023 18:12:22', 'component': '2016 Enviro500 SuperLo Diesel 8330', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8310', 'time': '11/02/2022 12:01:22', 'component': '2016 Enviro500 SuperLo Diesel 8310', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2614', 'time': '14/07/2021 15:41:34', 'component': '2015 D4500 Diesel 2614', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8326', 'time': '08/02/2023 14:26:36', 'component': '2016 Enviro500 SuperLo Diesel 8326', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8325', 'time': '11/03/2023 18:36:16', 'component': '2016 Enviro500 SuperLo Diesel 8325', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '516.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '516.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8383', 'time': '11/03/2023 14:20:25', 'component': '2018 Enviro500 SuperLo Diesel 8383', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8448', 'time': '11/03/2023 05:53:08', 'component': '2019 Enviro500 SuperLo Diesel 8448', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8460', 'time': '09/03/2023 10:08:23', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8460', 'time': '09/03/2023 10:08:21', 'component': '2019 Enviro500 SuperLo Diesel 8460', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8343', 'time': '08/03/2 ...
# [{'veh_id': '8330', 'time': '11/03/2023 18:12:22', 'component': '2016 Enviro500 SuperLo Diesel 8330', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8310', 'time': '11/02/2022 12:01:22', 'component': '2016 Enviro500 SuperLo Diesel 8310', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2614', 'time': '14/07/2021 15:41:34', 'component': '2015 D4500 Diesel 2614', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8326', 'time': '08/02/2023 14:26:36', 'component': '2016 Enviro500 SuperLo Diesel 8326', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8325', 'time': '11/03/2023 18:36:16', 'component': '2016 Enviro500 SuperLo Diesel 8325', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '516.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '516.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8383', 'time': '11/03/2023 14:20:25', 'component': '2018 Enviro500 SuperLo Diesel 8383', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8448', 'time': '11/03/2023 05:53:08', 'component': '2019 Enviro500 SuperLo Diesel 8448', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '512.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8460', 'time': '09/03/2023 10:08:23', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8460', 'time': '09/03/2023 10:08:21', 'component': '2019 Enviro500 SuperLo Diesel 8460', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8343', 'time': '08/03/2023 22:19:02', 'component': '2017 Enviro500 SuperLo Diesel 8343', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8436', 'time': '29/12/2022 14:20:13', 'component': '2019 Enviro500 SuperLo Diesel 8436', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# page_turner function called
# turned to next page -->
# entered while loop
# Page 2
# vehGridTableExtracter fucntion called
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8417', 'time': '11/03/2023 16:21:46', 'component': '2018 Enviro500 SuperLo Diesel 8417', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 12 /n 8417
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2451', 'time': '29/06/2021 15:10:35', 'component': '2011 D4500 D Diesel 2451', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 13 /n 2451
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8412', 'time': '08/03/2023 21:19:40', 'component': '2018 Enviro500 SuperLo Diesel 8412', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 14 /n 8412
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2574', 'time': '22/09/2020 14:23:20', 'component': '2014 D4500 Diesel 2574', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '2574', 'time': '05/03/2023 19:39:40', 'component': 'Transmission', 'error_code': 'P070C (3027 4)', 'status': 'Warning', 'message': {'failure code': 'P070C', 'SPN': '3027', 'FMI': '4', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Transmission #1'}, 'failure code': 'P070C', 'SPN': '3027', 'FMI': '4', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Transmission #1'}]
# 15 /n 2574
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2426', 'time': '04/12/2020 07:37:33', 'component': '2009 D4500 Diesel 2426', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 16 /n 2426
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2462', 'time': '02/10/2020 08:43:03', 'component': '2011 D4500 D Diesel 2462', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 17 /n 2462
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2511', 'time': '21/06/2020 11:31:34', 'component': '2012 D4500 Diesel 2511', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '20.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '20.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 18 /n 2511
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2534', 'time': '06/07/2021 16:22:21', 'component': '2012 D4500 Diesel 2534', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 19 /n 2534
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '2594', 'time': '21/09/2021 14:20:28', 'component': '2014 D4500 Diesel 2594', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 20 /n 2594
# no more to click: end of page
# Enter parser
# ---
#  [[{'veh_id': '8417', 'time': '11/03/2023 16:21:46', 'component': '2018 Enviro500 SuperLo Diesel 8417', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2451', 'time': '29/06/2021 15:10:35', 'component': '2011 D4500 D Diesel 2451', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8412', 'time': '08/03/2023 21:19:40', 'component': '2018 Enviro500 SuperLo Diesel 8412', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2574', 'time': '22/09/2020 14:23:20', 'component': '2014 D4500 Diesel 2574', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '2574', 'time': '05/03/2023 19:39:40', 'component': 'Transmission', 'error_code': 'P070C (3027 4)', 'status': 'Warning', 'message': {'failure code': 'P070C', 'SPN': '3027', 'FMI': '4', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Transmission #1'}, 'failure code': 'P070C', 'SPN': '3027', 'FMI': '4', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Transmission #1'}], [{'veh_id': '2426', 'time': '04/12/2020 07:37:33', 'component': '2009 D4500 Diesel 2426', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2462', 'time': '02/10/2020 08:43:03', 'component': '2011 D4500 D Diesel 2462', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2511', 'time': '21/06/2020 11:31:34', 'component': '2012 D4500 Diesel 2511', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '20.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '20.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2534', 'time': '06/07/2021 16:22:21', 'component': '2012 D4500 Diesel 2534', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '2594', 'time': '21/09/2021 14:20:28', 'component': '2014 D4500 Diesel 2594', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mo ...
# [{'veh_id': '8417', 'time': '11/03/2023 16:21:46', 'component': '2018 Enviro500 SuperLo Diesel 8417', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2451', 'time': '29/06/2021 15:10:35', 'component': '2011 D4500 D Diesel 2451', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8412', 'time': '08/03/2023 21:19:40', 'component': '2018 Enviro500 SuperLo Diesel 8412', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2574', 'time': '22/09/2020 14:23:20', 'component': '2014 D4500 Diesel 2574', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '2574', 'time': '05/03/2023 19:39:40', 'component': 'Transmission', 'error_code': 'P070C (3027 4)', 'status': 'Warning', 'message': {'failure code': 'P070C', 'SPN': '3027', 'FMI': '4', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Transmission #1'}, 'failure code': 'P070C', 'SPN': '3027', 'FMI': '4', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Transmission #1'}]
# [{'veh_id': '2426', 'time': '04/12/2020 07:37:33', 'component': '2009 D4500 Diesel 2426', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2462', 'time': '02/10/2020 08:43:03', 'component': '2011 D4500 D Diesel 2462', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2511', 'time': '21/06/2020 11:31:34', 'component': '2012 D4500 Diesel 2511', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '20.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '20.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2534', 'time': '06/07/2021 16:22:21', 'component': '2012 D4500 Diesel 2534', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '2594', 'time': '21/09/2021 14:20:28', 'component': '2014 D4500 Diesel 2594', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '1.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# page_turner function called
# turned to next page -->
# entered while loop
# Page 3
# vehGridTableExtracter fucntion called
# no more to click: end of page
# Enter parser
# ---
#  []
# could not parse data in vehGridTableParser
# page_turner function called
# turned to next page -->
# entered while loop
# Page 4
# vehGridTableExtracter fucntion called
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8387', 'time': '11/03/2023 13:46:15', 'component': '2018 Enviro500 SuperLo Diesel 8387', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 23 /n 8387
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8115', 'time': '12/01/2021 09:49:23', 'component': 'ABS', 'error_code': '7+1 (639 5)', 'status': 'Warning', 'message': {'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, 'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, {'veh_id': '8115', 'time': '12/01/2021 10:18:31', 'component': '2013 Enviro500 Diesel 8115', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '76.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '76.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 24 /n 8115
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8135', 'time': '04/05/2021 09:48:30', 'component': '2014 Enviro500 Diesel 8135', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '4157 (4376 7)', 'status': 'Warning', 'message': {'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, 'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '3714 (1569 31)', 'status': 'Warning', 'message': {'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, 'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}]
# 25 /n 8135
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8205', 'time': '06/07/2021 10:31:22', 'component': '2015 Enviro500 Diesel 8205', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '4157 (4376 7)', 'status': 'Warning', 'message': {'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, 'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '687 (103 18)', 'status': 'Warning', 'message': {'failure code': '687', 'SPN': '103', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': 'Data Valid But Below Normal Operating Range - Moderately Severe Level', 'ecuname': 'Engine #1'}, 'failure code': '687', 'SPN': '103', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': 'Data Valid But Below Normal Operating Range - Moderately Severe Level', 'ecuname': 'Engine #1'}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8205', 'time': '07/09/2021 15:12:38', 'component': 'ABS', 'error_code': '7+1 (639 5)', 'status': 'Warning', 'message': {'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, 'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}]
# 26 /n 8205
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '3232 (3216 9)', 'status': 'Warning', 'message': {'failure code': '3232', 'SPN': '3216', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '3232', 'SPN': '3216', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '2771 (3226 9)', 'status': 'Warning', 'message': {'failure code': '2771', 'SPN': '3226', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '2771', 'SPN': '3226', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '4151 (5742 9)', 'status': 'Warning', 'message': {'failure code': '4151', 'SPN': '5742', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '4151', 'SPN': '5742', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '4152 (5743 9)', 'status': 'Warning', 'message': {'failure code': '4152', 'SPN': '5743', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '4152', 'SPN': '5743', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '3714 (1569 31)', 'status': 'Warning', 'message': {'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, 'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:48', 'component': '2014 Enviro500 Diesel 8169', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8169', 'time': '22/06/2021 07:38:08', 'component': 'Engine', 'error_code': '1942 (101 2)', 'status': 'Warning', 'message': {'failure code': '1942', 'SPN': '101', 'FMI': '2', 'current value': None, 'alarm type': None, 'mode': 'Data erratic  intermittent or incorrect', 'ecuname': 'Engine #1'}, 'failure code': '1942', 'SPN': '101', 'FMI': '2', 'current value': None, 'alarm type': None, 'mode': 'Data erratic  intermittent or incorrect', 'ecuname': 'Engine #1'}]
# 27 /n 8169
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8124', 'time': '17/01/2022 00:46:30', 'component': 'unknown', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8124', 'time': '17/01/2022 00:46:30', 'component': '2013 Enviro500 Diesel 8124', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 28 /n 8124
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8548', 'time': '12/12/2022 05:39:55', 'component': '2020 Enviro500 SuperLo Diesel 8548', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 29 /n 8548
# TableExtracter fucntion called
# no more err to click
# [{'veh_id': '8540', 'time': '11/03/2023 16:18:50', 'component': '2020 Enviro500 SuperLo Diesel 8540', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '524.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '524.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# 30 /n 8540
# no more to click: end of page
# Enter parser
# ---
#  [[{'veh_id': '8387', 'time': '11/03/2023 13:46:15', 'component': '2018 Enviro500 SuperLo Diesel 8387', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8115', 'time': '12/01/2021 09:49:23', 'component': 'ABS', 'error_code': '7+1 (639 5)', 'status': 'Warning', 'message': {'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, 'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, {'veh_id': '8115', 'time': '12/01/2021 10:18:31', 'component': '2013 Enviro500 Diesel 8115', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '76.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '76.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}], [{'veh_id': '8135', 'time': '04/05/2021 09:48:30', 'component': '2014 Enviro500 Diesel 8135', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '4157 (4376 7)', 'status': 'Warning', 'message': {'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, 'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '3714 (1569 31)', 'status': 'Warning', 'message': {'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, 'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}], [{'veh_id': '8205', 'time': '06/07/2021 10:31:22', 'component': '2015 Enviro500 Diesel 8205', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '4157 (4376 7)', 'status': 'Warning', 'message': {'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, 'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': Non ...
# [{'veh_id': '8387', 'time': '11/03/2023 13:46:15', 'component': '2018 Enviro500 SuperLo Diesel 8387', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '508.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8115', 'time': '12/01/2021 09:49:23', 'component': 'ABS', 'error_code': '7+1 (639 5)', 'status': 'Warning', 'message': {'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, 'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, {'veh_id': '8115', 'time': '12/01/2021 10:18:31', 'component': '2013 Enviro500 Diesel 8115', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '76.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '76.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8135', 'time': '04/05/2021 09:48:30', 'component': '2014 Enviro500 Diesel 8135', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '4157 (4376 7)', 'status': 'Warning', 'message': {'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, 'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8135', 'time': '29/06/2021 14:42:09', 'component': 'Engine', 'error_code': '3714 (1569 31)', 'status': 'Warning', 'message': {'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, 'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}]
# [{'veh_id': '8205', 'time': '06/07/2021 10:31:22', 'component': '2015 Enviro500 Diesel 8205', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '4157 (4376 7)', 'status': 'Warning', 'message': {'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, 'failure code': '4157', 'SPN': '4376', 'FMI': '7', 'current value': None, 'alarm type': None, 'mode': 'Mechanical system not responding or out of adjustment', 'ecuname': 'Engine #1'}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '687 (103 18)', 'status': 'Warning', 'message': {'failure code': '687', 'SPN': '103', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': 'Data Valid But Below Normal Operating Range - Moderately Severe Level', 'ecuname': 'Engine #1'}, 'failure code': '687', 'SPN': '103', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': 'Data Valid But Below Normal Operating Range - Moderately Severe Level', 'ecuname': 'Engine #1'}, {'veh_id': '8205', 'time': '06/07/2021 13:34:19', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8205', 'time': '07/09/2021 15:12:38', 'component': 'ABS', 'error_code': '7+1 (639 5)', 'status': 'Warning', 'message': {'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}, 'failure code': '7+1', 'SPN': '639', 'FMI': '5', 'current value': None, 'alarm type': None, 'mode': '', 'ecuname': 'Brakes - System Controller'}]
# [{'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '3232 (3216 9)', 'status': 'Warning', 'message': {'failure code': '3232', 'SPN': '3216', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '3232', 'SPN': '3216', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '2771 (3226 9)', 'status': 'Warning', 'message': {'failure code': '2771', 'SPN': '3226', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '2771', 'SPN': '3226', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '4151 (5742 9)', 'status': 'Warning', 'message': {'failure code': '4151', 'SPN': '5742', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '4151', 'SPN': '5742', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '4152 (5743 9)', 'status': 'Warning', 'message': {'failure code': '4152', 'SPN': '5743', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, 'failure code': '4152', 'SPN': '5743', 'FMI': '9', 'current value': None, 'alarm type': None, 'mode': 'Abnormal update rate', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:49', 'component': 'Engine', 'error_code': '3714 (1569 31)', 'status': 'Warning', 'message': {'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, 'failure code': '3714', 'SPN': '1569', 'FMI': '31', 'current value': None, 'alarm type': None, 'mode': 'Condition Exists', 'ecuname': 'Engine #1'}, {'veh_id': '8169', 'time': '17/06/2021 10:16:48', 'component': '2014 Enviro500 Diesel 8169', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, {'veh_id': '8169', 'time': '22/06/2021 07:38:08', 'component': 'Engine', 'error_code': '1942 (101 2)', 'status': 'Warning', 'message': {'failure code': '1942', 'SPN': '101', 'FMI': '2', 'current value': None, 'alarm type': None, 'mode': 'Data erratic  intermittent or incorrect', 'ecuname': 'Engine #1'}, 'failure code': '1942', 'SPN': '101', 'FMI': '2', 'current value': None, 'alarm type': None, 'mode': 'Data erratic  intermittent or incorrect', 'ecuname': 'Engine #1'}]
# [{'veh_id': '8124', 'time': '17/01/2022 00:46:30', 'component': 'unknown', 'error_code': '197 (111 18)', 'status': 'Warning', 'message': {'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, 'failure code': '197', 'SPN': '111', 'FMI': '18', 'current value': None, 'alarm type': None, 'mode': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""', 'ecuname': 'Engine #1'}, {'veh_id': '8124', 'time': '17/01/2022 00:46:30', 'component': '2013 Enviro500 Diesel 8124', 'error_code': 'EngineCoolantLevel1', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '0.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8548', 'time': '12/12/2022 05:39:55', 'component': '2020 Enviro500 SuperLo Diesel 8548', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '504.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# [{'veh_id': '8540', 'time': '11/03/2023 16:18:50', 'component': '2020 Enviro500 SuperLo Diesel 8540', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': '524.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}, 'failure code': None, 'SPN': None, 'FMI': None, 'current value': '524.00', 'alarm type': 'outside', 'mode': None, 'ecuname': None}]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_1460\2754497405.py in <module>
#     251
#     252 #establishing the connection
# --> 253 conn = psycopg2.connect(
#     254    database=db, user=db_username, password=db_password, host=host, port= port_no
#     255 )
#
# NameError: name 'psycopg2' is not defined

# %%
data.to_csv(r"C:\Users\MelissaLu\OneDrive - Metrolinx\Desktop\IAM\real-time-control-board.csv")

# %%
def vehGridTableParser(dataList):
    df_list = []
    print(dataList)
    # for veh in dataList:
    #     print(veh)
    #     for r in veh:
    #         df = pd.DataFrame(veh).drop(columns=["message"])
    #         df_list.append(df)

    # data = pd.concat(df_list).reset_index().drop(columns=["index"])
    # return data

# vehGridTableParser(data_list)
print(data_list)
# Out:
# []

# %%
import psycopg2

from sqlalchemy import create_engine

# credentials
db = "mx_tester_db"
db_table = "mbl_eco2_ctrl_brd"
db_username ='postgres'
db_password='mxpassword'
db_host="localhost"
db_port='5432'

engine = create_engine(f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db}')


for r in data.iterrows():
    try:
        r[1].to_sql(      
            name=db_table,
            con=engine,
            if_exists="append"
        )
    except Exception as e:
        print(e)
# Out:
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "0") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "0") VALUES (%(index)s, %(0)s)]
# [parameters: ({'index': 'veh_id', '0': '8333'}, {'index': 'datetime', '0': '07/03/2023 10:02:06'}, {'index': 'component', '0': '2017 Enviro500 SuperLo Diesel 8333'}, {'index': 'error_code', '0': 'EngineOilPressure'}, {'index': 'status', '0': 'Error'}, {'index': 'failure_code', '0': None}, {'index': 'SPN', '0': None}, {'index': 'FMI', '0': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '0': None}, {'index': 'ecuname', '0': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "1") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "1") VALUES (%(index)s, %(1)s)]
# [parameters: ({'index': 'veh_id', '1': '8344'}, {'index': 'datetime', '1': '07/03/2023 04:11:08'}, {'index': 'component', '1': '2017 Enviro500 SuperLo Diesel 8344'}, {'index': 'error_code', '1': 'EngineOilPressure'}, {'index': 'status', '1': 'Error'}, {'index': 'failure_code', '1': None}, {'index': 'SPN', '1': None}, {'index': 'FMI', '1': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '1': None}, {'index': 'ecuname', '1': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "2") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "2") VALUES (%(index)s, %(2)s)]
# [parameters: ({'index': 'veh_id', '2': '8367'}, {'index': 'datetime', '2': '07/03/2023 12:25:06'}, {'index': 'component', '2': '2017 Enviro500 SuperLo Diesel 8367'}, {'index': 'error_code', '2': 'EngineOilPressure'}, {'index': 'status', '2': 'Error'}, {'index': 'failure_code', '2': None}, {'index': 'SPN', '2': None}, {'index': 'FMI', '2': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '2': None}, {'index': 'ecuname', '2': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "3") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "3") VALUES (%(index)s, %(3)s)]
# [parameters: ({'index': 'veh_id', '3': '8452'}, {'index': 'datetime', '3': '07/03/2023 13:43:30'}, {'index': 'component', '3': 'Engine'}, {'index': 'error_code', '3': '197 (111 18)'}, {'index': 'status', '3': 'Warning'}, {'index': 'failure_code', '3': '197'}, {'index': 'SPN', '3': '111'}, {'index': 'FMI', '3': '18'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '3': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""'}, {'index': 'ecuname', '3': 'Engine #1'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "4") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "4") VALUES (%(index)s, %(4)s)]
# [parameters: ({'index': 'veh_id', '4': '8452'}, {'index': 'datetime', '4': '07/03/2023 13:43:30'}, {'index': 'component', '4': '2019 Enviro500 SuperLo Diesel 8452'}, {'index': 'error_code', '4': 'EngineCoolantLevel1'}, {'index': 'status', '4': 'Error'}, {'index': 'failure_code', '4': None}, {'index': 'SPN', '4': None}, {'index': 'FMI', '4': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '4': None}, {'index': 'ecuname', '4': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "5") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "5") VALUES (%(index)s, %(5)s)]
# [parameters: ({'index': 'veh_id', '5': '8452'}, {'index': 'datetime', '5': '07/03/2023 13:43:30'}, {'index': 'component', '5': 'Engine'}, {'index': 'error_code', '5': '197 (111 18)'}, {'index': 'status', '5': 'Warning'}, {'index': 'failure_code', '5': '197'}, {'index': 'SPN', '5': '111'}, {'index': 'FMI', '5': '18'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '5': '"Data Valid But Below Normal Operating Range - Moderately Severe Level"""'}, {'index': 'ecuname', '5': 'Engine #1'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "6") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "6") VALUES (%(index)s, %(6)s)]
# [parameters: ({'index': 'veh_id', '6': '8452'}, {'index': 'datetime', '6': '07/03/2023 13:43:30'}, {'index': 'component', '6': '2019 Enviro500 SuperLo Diesel 8452'}, {'index': 'error_code', '6': 'EngineCoolantLevel1'}, {'index': 'status', '6': 'Error'}, {'index': 'failure_code', '6': None}, {'index': 'SPN', '6': None}, {'index': 'FMI', '6': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '6': None}, {'index': 'ecuname', '6': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "7") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "7") VALUES (%(index)s, %(7)s)]
# [parameters: ({'index': 'veh_id', '7': '2458'}, {'index': 'datetime', '7': '07/03/2023 17:04:33'}, {'index': 'component', '7': 'ABS'}, {'index': 'error_code', '7': 'Empty (639 14)'}, {'index': 'status', '7': 'Warning'}, {'index': 'failure_code', '7': 'Empty'}, {'index': 'SPN', '7': '639'}, {'index': 'FMI', '7': '14'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '7': 'Special Instructions'}, {'index': 'ecuname', '7': 'Brakes - System Controller'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "8") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "8") VALUES (%(index)s, %(8)s)]
# [parameters: ({'index': 'veh_id', '8': '2458'}, {'index': 'datetime', '8': '07/03/2023 17:04:41'}, {'index': 'component', '8': 'ABS'}, {'index': 'error_code', '8': '7+1 (639 9)'}, {'index': 'status', '8': 'Warning'}, {'index': 'failure_code', '8': '7+1'}, {'index': 'SPN', '8': '639'}, {'index': 'FMI', '8': '9'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '8': ''}, {'index': 'ecuname', '8': 'Brakes - System Controller'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "9") VALUES ('veh_id',...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "9") VALUES (%(index)s, %(9)s)]
# [parameters: ({'index': 'veh_id', '9': '2458'}, {'index': 'datetime', '9': '07/03/2023 17:04:41'}, {'index': 'component', '9': '2011 D4500 D Diesel 2458'}, {'index': 'error_code', '9': 'EngineCoolantTemp'}, {'index': 'status', '9': 'Error'}, {'index': 'failure_code', '9': None}, {'index': 'SPN', '9': None}, {'index': 'FMI', '9': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '9': None}, {'index': 'ecuname', '9': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "10") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "10") VALUES (%(index)s, %(10)s)]
# [parameters: ({'index': 'veh_id', '10': '2458'}, {'index': 'datetime', '10': '07/03/2023 17:04:33'}, {'index': 'component', '10': 'ABS'}, {'index': 'error_code', '10': 'Empty (639 14)'}, {'index': 'status', '10': 'Warning'}, {'index': 'failure_code', '10': 'Empty'}, {'index': 'SPN', '10': '639'}, {'index': 'FMI', '10': '14'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '10': 'Special Instructions'}, {'index': 'ecuname', '10': 'Brakes - System Controller'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "11") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "11") VALUES (%(index)s, %(11)s)]
# [parameters: ({'index': 'veh_id', '11': '2458'}, {'index': 'datetime', '11': '07/03/2023 17:04:41'}, {'index': 'component', '11': 'ABS'}, {'index': 'error_code', '11': '7+1 (639 9)'}, {'index': 'status', '11': 'Warning'}, {'index': 'failure_code', '11': '7+1'}, {'index': 'SPN', '11': '639'}, {'index': 'FMI', '11': '9'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '11': ''}, {'index': 'ecuname', '11': 'Brakes - System Controller'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "12") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "12") VALUES (%(index)s, %(12)s)]
# [parameters: ({'index': 'veh_id', '12': '2458'}, {'index': 'datetime', '12': '07/03/2023 17:04:41'}, {'index': 'component', '12': '2011 D4500 D Diesel 2458'}, {'index': 'error_code', '12': 'EngineCoolantTemp'}, {'index': 'status', '12': 'Error'}, {'index': 'failure_code', '12': None}, {'index': 'SPN', '12': None}, {'index': 'FMI', '12': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '12': None}, {'index': 'ecuname', '12': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "13") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "13") VALUES (%(index)s, %(13)s)]
# [parameters: ({'index': 'veh_id', '13': '2458'}, {'index': 'datetime', '13': '07/03/2023 17:04:33'}, {'index': 'component', '13': 'ABS'}, {'index': 'error_code', '13': 'Empty (639 14)'}, {'index': 'status', '13': 'Warning'}, {'index': 'failure_code', '13': 'Empty'}, {'index': 'SPN', '13': '639'}, {'index': 'FMI', '13': '14'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '13': 'Special Instructions'}, {'index': 'ecuname', '13': 'Brakes - System Controller'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "14") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "14") VALUES (%(index)s, %(14)s)]
# [parameters: ({'index': 'veh_id', '14': '2458'}, {'index': 'datetime', '14': '07/03/2023 17:04:41'}, {'index': 'component', '14': 'ABS'}, {'index': 'error_code', '14': '7+1 (639 9)'}, {'index': 'status', '14': 'Warning'}, {'index': 'failure_code', '14': '7+1'}, {'index': 'SPN', '14': '639'}, {'index': 'FMI', '14': '9'}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '14': ''}, {'index': 'ecuname', '14': 'Brakes - System Controller'})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "15") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "15") VALUES (%(index)s, %(15)s)]
# [parameters: ({'index': 'veh_id', '15': '2458'}, {'index': 'datetime', '15': '07/03/2023 17:04:41'}, {'index': 'component', '15': '2011 D4500 D Diesel 2458'}, {'index': 'error_code', '15': 'EngineCoolantTemp'}, {'index': 'status', '15': 'Error'}, {'index': 'failure_code', '15': None}, {'index': 'SPN', '15': None}, {'index': 'FMI', '15': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '15': None}, {'index': 'ecuname', '15': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "16") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "16") VALUES (%(index)s, %(16)s)]
# [parameters: ({'index': 'veh_id', '16': '2462'}, {'index': 'datetime', '16': '02/10/2020 08:43:03'}, {'index': 'component', '16': '2011 D4500 D Diesel 2462'}, {'index': 'error_code', '16': 'Idling'}, {'index': 'status', '16': 'Error'}, {'index': 'failure_code', '16': None}, {'index': 'SPN', '16': None}, {'index': 'FMI', '16': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '16': None}, {'index': 'ecuname', '16': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "17") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "17") VALUES (%(index)s, %(17)s)]
# [parameters: ({'index': 'veh_id', '17': '8544'}, {'index': 'datetime', '17': '07/03/2023 14:37:12'}, {'index': 'component', '17': '2020 Enviro500 SuperLo Diesel 8544'}, {'index': 'error_code', '17': 'EngineOilPressure'}, {'index': 'status', '17': 'Error'}, {'index': 'failure_code', '17': None}, {'index': 'SPN', '17': None}, {'index': 'FMI', '17': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '17': None}, {'index': 'ecuname', '17': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "18") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "18") VALUES (%(index)s, %(18)s)]
# [parameters: ({'index': 'veh_id', '18': '8525'}, {'index': 'datetime', '18': '07/03/2023 07:13:30'}, {'index': 'component', '18': '2020 Enviro500 SuperLo Diesel 8525'}, {'index': 'error_code', '18': 'EngineOilPressure'}, {'index': 'status', '18': 'Error'}, {'index': 'failure_code', '18': None}, {'index': 'SPN', '18': None}, {'index': 'FMI', '18': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '18': None}, {'index': 'ecuname', '18': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)
# (psycopg2.errors.UndefinedColumn) column "index" of relation "mbl_eco2_ctrl_brd" does not exist
# LINE 1: INSERT INTO mbl_eco2_ctrl_brd (index, "19") VALUES ('veh_id'...
#                                        ^
#
# [SQL: INSERT INTO mbl_eco2_ctrl_brd (index, "19") VALUES (%(index)s, %(19)s)]
# [parameters: ({'index': 'veh_id', '19': '8521'}, {'index': 'datetime', '19': '06/03/2023 08:24:06'}, {'index': 'component', '19': '2019 Enviro500 SuperLo Diesel 8521'}, {'index': 'error_code', '19': 'EngineOilPressure'}, {'index': 'status', '19': 'Error'}, {'index': 'failure_code', '19': None}, {'index': 'SPN', '19': None}, {'index': 'FMI', '19': None}  ... displaying 10 of 12 total bound parameter sets ...  {'index': 'mode', '19': None}, {'index': 'ecuname', '19': None})]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
import pandas as pd

#Fields: ----- [veh-id-row] | veh_id | time | component | error_code | status | 
# -------------[msg] | SPN | FMI | current value | alarm type | mode | ecuname |
# df idx cols :  veh_id | time | component | error_code | status 
# 
df_list = []
for veh in vehGridDataList:
    # print(veh)
    for r in veh:
        df_1 = pd.DataFrame(r)
        # df_2 = pd.DataFrame(r["message"])
        print(r)
        # print("df1")
        display(df_1)
        # print("df2")
        display(df_2)
        # df = pd.concat([df_1,df_2],axis=1,join="inner")
        # df_list.append(df)



# data = pd.concat(df_list).reset_index().drop(columns=["index"])
# display(data)
# print(len(data))

        # for row in veh:
        #     message = row["message"]
        #     idx_cols=['veh_id','time','component','error_code','status']
        #     # data = pd.DataFrame(message)
        #     # display(data)
        #     print(row,"\n----\n",message,"\n----\n")
        #     break


    
    # data = vehGridData[r]
    # data1 = data["message"]
    # print(data1)
# Out:
# {'veh_id': '8518', 'time': '06/03/2023 06:37:03', 'component': '2019 Enviro500 SuperLo Diesel 8518', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['508.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
# SPN             8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
# alarm type      8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
# current value   8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
# ecuname         8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
# failure code    8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
# mode            8518  06/03/2023 06:37:03  2019 Enviro500 SuperLo Diesel 8518
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [508.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8418', 'time': '06/03/2023 07:30:31', 'component': '2018 Enviro500 SuperLo Diesel 8418', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['504.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
# SPN             8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
# alarm type      8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
# current value   8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
# ecuname         8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
# failure code    8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
# mode            8418  06/03/2023 07:30:31  2018 Enviro500 SuperLo Diesel 8418
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [504.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8480', 'time': '06/03/2023 15:36:42', 'component': '2019 Enviro500 SuperLo Diesel 8480', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['504.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
# SPN             8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
# alarm type      8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
# current value   8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
# ecuname         8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
# failure code    8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
# mode            8480  06/03/2023 15:36:42  2019 Enviro500 SuperLo Diesel 8480
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [504.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8504', 'time': '06/03/2023 04:23:43', 'component': '2019 Enviro500 SuperLo Diesel 8504', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['504.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
# SPN             8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
# alarm type      8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
# current value   8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
# ecuname         8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
# failure code    8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
# mode            8504  06/03/2023 04:23:43  2019 Enviro500 SuperLo Diesel 8504
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [504.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '2451', 'time': '29/06/2021 15:10:35', 'component': '2011 D4500 D Diesel 2451', 'error_code': 'Idling', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['1.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                 component  \
# FMI             2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
# SPN             2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
# alarm type      2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
# current value   2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
# ecuname         2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
# failure code    2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
# mode            2451  29/06/2021 15:10:35  2011 D4500 D Diesel 2451
#
#               error_code status    message
# FMI               Idling  Error       None
# SPN               Idling  Error       None
# alarm type        Idling  Error  [outside]
# current value     Idling  Error     [1.00]
# ecuname           Idling  Error       None
# failure code      Idling  Error       None
# mode              Idling  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8415', 'time': '06/03/2023 05:38:15', 'component': '2018 Enviro500 SuperLo Diesel 8415', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['504.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
# SPN             8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
# alarm type      8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
# current value   8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
# ecuname         8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
# failure code    8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
# mode            8415  06/03/2023 05:38:15  2018 Enviro500 SuperLo Diesel 8415
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [504.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8351', 'time': '06/03/2023 12:10:13', 'component': '2017 Enviro500 SuperLo Diesel 8351', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['508.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
# SPN             8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
# alarm type      8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
# current value   8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
# ecuname         8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
# failure code    8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
# mode            8351  06/03/2023 12:10:13  2017 Enviro500 SuperLo Diesel 8351
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [508.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8544', 'time': '06/03/2023 00:47:46', 'component': 'unknown', 'error_code': 'Empty (1326 11)', 'status': 'Warning', 'message': {'failure code': ['Empty'], 'SPN': ['1326'], 'FMI': ['11'], 'current value': None, 'alarm type': None, 'mode': ['Root Cause Not Known'], 'ecuname': ['Engine #1']}}
#               veh_id                 time component       error_code   status  \
# FMI             8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
# SPN             8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
# alarm type      8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
# current value   8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
# ecuname         8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
# failure code    8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
# mode            8544  06/03/2023 00:47:46   unknown  Empty (1326 11)  Warning
#
#                               message
# FMI                              [11]
# SPN                            [1326]
# alarm type                       None
# current value                    None
# ecuname                   [Engine #1]
# failure code                  [Empty]
# mode           [Root Cause Not Known]
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8544', 'time': '06/03/2023 05:35:32', 'component': '2020 Enviro500 SuperLo Diesel 8544', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['532.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
# SPN             8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
# alarm type      8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
# current value   8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
# ecuname         8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
# failure code    8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
# mode            8544  06/03/2023 05:35:32  2020 Enviro500 SuperLo Diesel 8544
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [532.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None
# {'veh_id': '8532', 'time': '06/03/2023 13:07:21', 'component': '2020 Enviro500 SuperLo Diesel 8532', 'error_code': 'EngineOilPressure', 'status': 'Error', 'message': {'failure code': None, 'SPN': None, 'FMI': None, 'current value': ['508.00'], 'alarm type': ['outside'], 'mode': None, 'ecuname': None}}
#               veh_id                 time                           component  \
# FMI             8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
# SPN             8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
# alarm type      8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
# current value   8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
# ecuname         8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
# failure code    8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
# mode            8532  06/03/2023 13:07:21  2020 Enviro500 SuperLo Diesel 8532
#
#                       error_code status    message
# FMI            EngineOilPressure  Error       None
# SPN            EngineOilPressure  Error       None
# alarm type     EngineOilPressure  Error  [outside]
# current value  EngineOilPressure  Error   [508.00]
# ecuname        EngineOilPressure  Error       None
# failure code   EngineOilPressure  Error       None
# mode           EngineOilPressure  Error       None
#   failure code   SPN   FMI current value alarm type  mode ecuname
# 0         None  None  None        508.00    outside  None    None

# %%
msg_err1 ="EngineOilPressure outside limit (current value:508.00, alarm type:outside, lower limit:0.00, upper limit:500.00)"
# msg_err ="J1939 Network #1, Primary Vehicle Network (mode:Special Instructions; failure code:Empty; SPN:639; FMI:14;) (ecuname:Brakes - System Controller)"
msg_dict1 = {msg_err1:{'mode':"",'current value':"",'alarm type':"",'ecuname':""},}


for msg in msg_dict1[msg_err1]:
        pat1=fr'{msg}:(.*?)[;,)]'
        print(msg,"\n")
        # pat1 = r'\((.*?)\)'
        # msg_prs = " ".join(re.findall(pat,msg_err))
        # pat2 =fr'({msg}:)(.*?)\,|;'
        # pat2 =fr'({msg}:)(.*?)[;\*\,]'
        # print(msg_prs)
        if re.search(pat1,msg_err1):
                print("Found")
                print(re.findall(pat1,msg_err1)[0])
# Out:
# mode
#
# current value
#
# Found
# 508.00
# alarm type
#
# Found
# outside
# ecuname

# %%
import psycopg2

# credentials
db = "mx_tester_db"
db_table = "mbl_eco2_ctrl_brd"
username ='postgres'
password='mxpassword'

#establishing the connection
conn = psycopg2.connect(
   database=db, user=username, password=password, host='127.0.0.1', port= '5432'
)
#Creating a cursor object using the cursor() method
cursor = conn.cursor()


for row in data.iterrows():
   row.to_sql(
      name=db_table,
      conn=conn,
      if_exists=fail
   )

from sqlalchemy import create_engine, text

engine = create_engine(postgresql://username:pass@host:port/dbname)
query = text(f""" 
                INSERT INTO schema.table(name, title, id)
                VALUES {','.join([str(i) for i in list(data.to_records(index=False))])}
                ON CONFLICT (id)
                DO  UPDATE SET name= excluded.name,
                               title= excluded.title
         """)
engine.execute(query)
